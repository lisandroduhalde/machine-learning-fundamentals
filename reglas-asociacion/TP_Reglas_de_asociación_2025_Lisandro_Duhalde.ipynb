# %% [markdown]
# # **Trabajo Práctico - Reglas de Asociación - Lisandro Duhalde**

# %% [markdown]
# En este trabajo se aplican reglas de asociación para el análisis de patrones frecuentes en un conjunto de datos transaccionales.
# Se utiliza el algoritmo Apriori para identificar itemsets frecuentes y extraer reglas de asociación relevantes, evaluándolas mediante métricas como soporte, confianza y lift.
#
# El objetivo es descubrir relaciones significativas entre los elementos del dataset y analizar su interpretación desde el punto de vista del negocio/dominio del problema.

# %% [markdown]
# ## Técnicas utilizadas
# - Reglas de asociación
# - Algoritmo Apriori
# - Soporte, confianza y lift

# %%
import warnings

# Ignorar DeprecationWarning del modulo jupyter_client
warnings.filterwarnings("ignore", category=DeprecationWarning, module="jupyter_client")

# %% [markdown]
# Cargamos la librería que nos permite acceder al dataset

# %%
# soporte para cargar dataset de https://www.openml.org/
# !pip install openml
import openml
# Out:
# Collecting openml
#   Downloading openml-0.15.1-py3-none-any.whl.metadata (10 kB)
# Collecting liac-arff>=2.4.0 (from openml)
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting xmltodict (from openml)
#   Downloading xmltodict-1.0.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from openml) (2.32.4)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.12/dist-packages (from openml) (1.6.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from openml) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from openml) (2.2.2)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from openml) (1.16.2)
# Requirement already satisfied: numpy>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from openml) (2.0.2)
# Collecting minio (from openml)
#   Downloading minio-7.2.18-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from openml) (18.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openml) (4.67.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from openml) (25.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->openml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->openml) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->openml) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->openml) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->openml) (3.6.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from minio->openml) (25.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from minio->openml) (2025.8.3)
# Collecting pycryptodome (from minio->openml)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from minio->openml) (4.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from minio->openml) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->openml) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->openml) (3.10)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->minio->openml) (25.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml) (2.23)
# Downloading openml-0.15.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 4.7 MB/s eta 0:00:00
# Downloading minio-7.2.18-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 3.3 MB/s eta 0:00:00
# Downloading xmltodict-1.0.2-py3-none-any.whl (13 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.0 MB/s eta 0:00:00
# Building wheels for collected packages: liac-arff
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11717 sha256=c936be80e3645fbdbfc17e4192bdc7736cba17ba6ba845b2829ad4e24525a2bd
#   Stored in directory: /root/.cache/pip/wheels/a9/ac/cf/c2919807a5c623926d217c0a18eb5b457e5c19d242c3b5963a
# Successfully built liac-arff
# Installing collected packages: xmltodict, pycryptodome, liac-arff, minio, openml
# Successfully installed liac-arff-2.5.0 minio-7.2.18 openml-0.15.1 pycryptodome-3.23.0 xmltodict-1.0.2

# %% [markdown]
# Accedemos al dataset

# %%
import pandas as pd

# indicamos cual dataset queremos utilizar, en este caso el nro. 24
dataset = openml.datasets.get_dataset(42585)

# separamos las información almacenada en el dataset
X, y, categorical_indicator, attribute_names = dataset.get_data(
    dataset_format='dataframe',
    target=dataset.default_target_attribute
)

#  concatenamos la información relevante en un único DataFrame
df = pd.concat([X, y], axis=1)
df
# Out:
#         island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Torgersen              39.1             18.7              181.0
# 1    Torgersen              39.5             17.4              186.0
# 2    Torgersen              40.3             18.0              195.0
# 3    Torgersen               NaN              NaN                NaN
# 4    Torgersen              36.7             19.3              193.0
# ..         ...               ...              ...                ...
# 339     Biscoe               NaN              NaN                NaN
# 340     Biscoe              46.8             14.3              215.0
# 341     Biscoe              50.4             15.7              222.0
# 342     Biscoe              45.2             14.8              212.0
# 343     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex species
# 0         3750.0    MALE  Adelie
# 1         3800.0  FEMALE  Adelie
# 2         3250.0  FEMALE  Adelie
# 3            NaN     NaN  Adelie
# 4         3450.0  FEMALE  Adelie
# ..           ...     ...     ...
# 339          NaN     NaN  Gentoo
# 340       4850.0  FEMALE  Gentoo
# 341       5750.0    MALE  Gentoo
# 342       5200.0  FEMALE  Gentoo
# 343       5400.0    MALE  Gentoo
#
# [344 rows x 7 columns]

# %% [markdown]
# a) El dataset seleccionado contiene información sobre pingüinos de la base Palmer, un laboratorio en la Antártida. Sobre un total de 344 pingüinos, se los clasifica de acuerdo con 7 características.
#
# Dentro de las 7 características, la especie, la isla y el sexo son de tipo nominal, y solo pueden tomar 3 valores. El resto son de tipo numérico y pueden tomar un rango mayor de valores.

# %% [markdown]
# b) Aplicar las reglas de asociación en este dataset puede ser útil para encontrar distintos tipos de relaciones entre las variables estudiadas, como por ejemplo si dentro de alguna isla predomina alguna especie, o cómo varía el peso de los pingüinos por especie/isla, también cómo varían las medidas de los pingüinos de distinta especie/género, etc.

# %% [markdown]
# c) Para las filas con valores faltantes, se eliminaran esas filas, ya que para discretizar los intervalos es necesario remover los valores faltantes; para la variable 'sex', se reemplazaron las celdas con valor '_' por NaN para que las elimine correctamente la funcion 'dropna'.
#
# Luego vamos a discretizar en 3 intervalos a las variables continuas.
#
# Y por ultimo se utilizara One-Hod Encoding para que algoritmo Apiori funcione correctamente.

# %%
import pandas as pd
from sklearn.preprocessing import KBinsDiscretizer

df['sex'] = df['sex'].replace('_', pd.NA)

columnas_cat = ["island","sex","species"]
df_limpio = df.dropna(subset=columnas_cat)

columnas_cont = ["culmen_length_mm", "culmen_depth_mm", "flipper_length_mm", "body_mass_g"]
kbd = KBinsDiscretizer(n_bins=3, encode="ordinal", strategy="quantile")
df_limpio[columnas_cont] = kbd.fit_transform(df_limpio[columnas_cont])

df_procesado = pd.get_dummies(df_limpio, columns=columnas_cat + columnas_cont)
df_procesado
# Out:
# /tmp/ipython-input-1679303345.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio[columnas_cont] = kbd.fit_transform(df_limpio[columnas_cont])
#      island_Biscoe  island_Dream  island_Torgersen  sex_FEMALE  sex_MALE  \
# 0            False         False              True       False      True
# 1            False         False              True        True     False
# 2            False         False              True        True     False
# 4            False         False              True        True     False
# 5            False         False              True       False      True
# ..             ...           ...               ...         ...       ...
# 338           True         False             False        True     False
# 340           True         False             False        True     False
# 341           True         False             False       False      True
# 342           True         False             False        True     False
# 343           True         False             False       False      True
#
#      species_Adelie  species_Chinstrap  species_Gentoo  culmen_length_mm_0.0  \
# 0              True              False           False                  True
# 1              True              False           False                  True
# 2              True              False           False                  True
# 4              True              False           False                  True
# 5              True              False           False                  True
# ..              ...                ...             ...                   ...
# 338           False              False            True                 False
# 340           False              False            True                 False
# 341           False              False            True                 False
# 342           False              False            True                 False
# 343           False              False            True                 False
#
#      culmen_length_mm_1.0  culmen_length_mm_2.0  culmen_depth_mm_0.0  \
# 0                   False                 False                False
# 1                   False                 False                False
# 2                   False                 False                False
# 4                   False                 False                False
# 5                   False                 False                False
# ..                    ...                   ...                  ...
# 338                 False                  True                 True
# 340                 False                  True                 True
# 341                 False                  True                 True
# 342                  True                 False                 True
# 343                 False                  True                 True
#
#      culmen_depth_mm_1.0  culmen_depth_mm_2.0  flipper_length_mm_0.0  \
# 0                  False                 True                   True
# 1                   True                False                   True
# 2                   True                False                  False
# 4                  False                 True                  False
# 5                  False                 True                   True
# ..                   ...                  ...                    ...
# 338                False                False                  False
# 340                False                False                  False
# 341                False                False                  False
# 342                False                False                  False
# 343                False                False                  False
#
#      flipper_length_mm_1.0  flipper_length_mm_2.0  body_mass_g_0.0  \
# 0                    False                  False            False
# 1                    False                  False            False
# 2                     True                  False             True
# 4                     True                  False             True
# 5                    False                  False             True
# ..                     ...                    ...              ...
# 338                  False                   True            False
# 340                  False                   True            False
# 341                  False                   True            False
# 342                  False                   True            False
# 343                  False                   True            False
#
#      body_mass_g_1.0  body_mass_g_2.0
# 0               True            False
# 1               True            False
# 2              False            False
# 4              False            False
# 5              False            False
# ..               ...              ...
# 338            False             True
# 340            False             True
# 341            False             True
# 342            False             True
# 343            False             True
#
# [333 rows x 20 columns]

# %% [markdown]
# d) Para obtener las reglas de asociación, primero obtenemos los itemsets frecuentes a partir del algoritmo Apriori y luego generamos las reglas de asociación a partir de esos itemsets.El soporte (0.15) y la confianza (0.75) poseen valores moderados, ya que luego en la etapa de post procesamiento se van a filtrar un poco mas las reglas irrelelevantes.

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

frequent_itemsets = apriori(df_procesado, min_support=0.15,use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.75)

rules
# Out:
#                                            antecedents  \
# 0                                     (species_Gentoo)
# 1                                (culmen_depth_mm_0.0)
# 2                              (flipper_length_mm_2.0)
# 3                                    (body_mass_g_2.0)
# 4                                  (species_Chinstrap)
# ..                                                 ...
# 617  (culmen_length_mm_2.0, culmen_depth_mm_0.0, bo...
# 618  (culmen_length_mm_2.0, flipper_length_mm_2.0, ...
# 619              (island_Biscoe, culmen_length_mm_2.0)
# 620             (culmen_length_mm_2.0, species_Gentoo)
# 621        (culmen_length_mm_2.0, culmen_depth_mm_0.0)
#
#                                            consequents  antecedent support  \
# 0                                      (island_Biscoe)            0.357357
# 1                                      (island_Biscoe)            0.327327
# 2                                      (island_Biscoe)            0.345345
# 3                                      (island_Biscoe)            0.336336
# 4                                       (island_Dream)            0.204204
# ..                                                 ...                 ...
# 617  (island_Biscoe, species_Gentoo, flipper_length...            0.159159
# 618   (island_Biscoe, species_Gentoo, body_mass_g_2.0)            0.156156
# 619  (culmen_depth_mm_0.0, flipper_length_mm_2.0, s...            0.201201
# 620  (culmen_depth_mm_0.0, island_Biscoe, flipper_l...            0.201201
# 621  (flipper_length_mm_2.0, island_Biscoe, species...            0.162162
#
#      consequent support   support  confidence      lift  representativity  \
# 0              0.489489  0.357357    1.000000  2.042945               1.0
# 1              0.489489  0.315315    0.963303  1.967974               1.0
# 2              0.489489  0.330330    0.956522  1.954121               1.0
# 3              0.489489  0.318318    0.946429  1.933501               1.0
# 4              0.369369  0.204204    1.000000  2.707317               1.0
# ..                  ...       ...         ...       ...               ...
# 617            0.330330  0.153153    0.962264  2.913036               1.0
# 618            0.309309  0.153153    0.980769  3.170836               1.0
# 619            0.252252  0.153153    0.761194  3.017591               1.0
# 620            0.252252  0.153153    0.761194  3.017591               1.0
# 621            0.297297  0.153153    0.944444  3.176768               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.182435         inf       0.794393  0.730061   1.000000    0.865031
# 1    0.155092   13.911411       0.731207  0.628743   0.928117    0.803737
# 2    0.161287   11.741742       0.745830  0.654762   0.914834    0.815684
# 3    0.153685    9.529530       0.727482  0.627219   0.895063    0.798368
# 4    0.128777         inf       0.792453  0.552846   1.000000    0.776423
# ..        ...         ...            ...       ...        ...         ...
# 617  0.100578   17.746246       0.781022  0.455357   0.943650    0.712950
# 618  0.104853   35.915916       0.811318  0.490385   0.972157    0.737957
# 619  0.102400    3.131194       0.837019  0.510000   0.680633    0.684168
# 620  0.102400    3.131194       0.837019  0.510000   0.680633    0.684168
# 621  0.104943   12.648649       0.817837  0.500000   0.920940    0.729798
#
# [622 rows x 14 columns]

# %% [markdown]
# e) Para la etapa de post procesamiento, ademas de haber utilizado soporte y confianza previamente, vamos a utilizar valores altos para lift (2) y conviction (3), para filtrar reglas que no sean utiles.

# %%
rules_filtradas = rules[(rules['conviction'] > 3) & (rules['lift'] > 2)]

rules_filtradas
# Out:
#                                            antecedents  \
# 0                                     (species_Gentoo)
# 4                                  (species_Chinstrap)
# 8                               (culmen_length_mm_0.0)
# 11                                    (species_Gentoo)
# 12                               (culmen_depth_mm_0.0)
# ..                                                 ...
# 617  (culmen_length_mm_2.0, culmen_depth_mm_0.0, bo...
# 618  (culmen_length_mm_2.0, flipper_length_mm_2.0, ...
# 619              (island_Biscoe, culmen_length_mm_2.0)
# 620             (culmen_length_mm_2.0, species_Gentoo)
# 621        (culmen_length_mm_2.0, culmen_depth_mm_0.0)
#
#                                            consequents  antecedent support  \
# 0                                      (island_Biscoe)            0.357357
# 4                                       (island_Dream)            0.204204
# 8                                     (species_Adelie)            0.333333
# 11                               (culmen_depth_mm_0.0)            0.357357
# 12                                    (species_Gentoo)            0.327327
# ..                                                 ...                 ...
# 617  (island_Biscoe, species_Gentoo, flipper_length...            0.159159
# 618   (island_Biscoe, species_Gentoo, body_mass_g_2.0)            0.156156
# 619  (culmen_depth_mm_0.0, flipper_length_mm_2.0, s...            0.201201
# 620  (culmen_depth_mm_0.0, island_Biscoe, flipper_l...            0.201201
# 621  (flipper_length_mm_2.0, island_Biscoe, species...            0.162162
#
#      consequent support   support  confidence      lift  representativity  \
# 0              0.489489  0.357357    1.000000  2.042945               1.0
# 4              0.369369  0.204204    1.000000  2.707317               1.0
# 8              0.438438  0.333333    1.000000  2.280822               1.0
# 11             0.327327  0.312312    0.873950  2.669956               1.0
# 12             0.357357  0.312312    0.954128  2.669956               1.0
# ..                  ...       ...         ...       ...               ...
# 617            0.330330  0.153153    0.962264  2.913036               1.0
# 618            0.309309  0.153153    0.980769  3.170836               1.0
# 619            0.252252  0.153153    0.761194  3.017591               1.0
# 620            0.252252  0.153153    0.761194  3.017591               1.0
# 621            0.297297  0.153153    0.944444  3.176768               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.182435         inf       0.794393  0.730061   1.000000    0.865031
# 4    0.128777         inf       0.792453  0.552846   1.000000    0.776423
# 8    0.187187         inf       0.842342  0.760274   1.000000    0.880137
# 11   0.195339    5.336537       0.973266  0.838710   0.812613    0.914039
# 12   0.195339   14.009610       0.929816  0.838710   0.928620    0.914039
# ..        ...         ...            ...       ...        ...         ...
# 617  0.100578   17.746246       0.781022  0.455357   0.943650    0.712950
# 618  0.104853   35.915916       0.811318  0.490385   0.972157    0.737957
# 619  0.102400    3.131194       0.837019  0.510000   0.680633    0.684168
# 620  0.102400    3.131194       0.837019  0.510000   0.680633    0.684168
# 621  0.104943   12.648649       0.817837  0.500000   0.920940    0.729798
#
# [568 rows x 14 columns]

# %% [markdown]
# f) Para analizar las reglas vamos a ordenarlas por lift.
#
# En la tabla se pueden obtener muchos patrones a partir de las reglas, entre ellos la relacion entre especie y isla que habita, por ejemplo, los pinguinos de especie Gentoo habitan mucho la isla Biscoe. Luego los machos suelen tener mayor altura y peso. Estos son algunos ejemplos, luego se puede analizar en profundidad para obtener mas patrones.

# %%
pd.set_option("display.max_colwidth", None)

rules_filtradas_ordenadas = rules_filtradas.sort_values(by="lift", ascending=False)
rules_filtradas_ordenadas[["antecedents","consequents","support","confidence","lift","conviction"]].head(30)
# Out:
#                                                                        antecedents  \
# 592                                                     (sex_MALE, species_Gentoo)
# 570  (culmen_length_mm_2.0, island_Biscoe, flipper_length_mm_2.0, body_mass_g_2.0)
# 420                                                     (sex_MALE, species_Gentoo)
# 413                         (island_Biscoe, culmen_length_mm_2.0, body_mass_g_2.0)
# 584                        (culmen_length_mm_2.0, species_Gentoo, body_mass_g_2.0)
# 579                         (island_Biscoe, culmen_length_mm_2.0, body_mass_g_2.0)
# 585                              (sex_MALE, species_Gentoo, flipper_length_mm_2.0)
# 580                               (island_Biscoe, sex_MALE, flipper_length_mm_2.0)
# 577                                      (sex_MALE, island_Biscoe, species_Gentoo)
# 543                                                     (sex_MALE, species_Gentoo)
# 403                                                     (sex_MALE, species_Gentoo)
# 583                                    (sex_MALE, species_Gentoo, body_mass_g_2.0)
# 582                   (culmen_length_mm_2.0, island_Biscoe, flipper_length_mm_2.0)
# 398                   (culmen_length_mm_2.0, island_Biscoe, flipper_length_mm_2.0)
# 590                 (culmen_length_mm_2.0, flipper_length_mm_2.0, body_mass_g_2.0)
# 541                 (culmen_length_mm_2.0, flipper_length_mm_2.0, body_mass_g_2.0)
# 415                                    (sex_MALE, species_Gentoo, body_mass_g_2.0)
# 183                                          (island_Biscoe, culmen_length_mm_2.0)
# 419                                          (island_Biscoe, culmen_length_mm_2.0)
# 181                                                     (species_Gentoo, sex_MALE)
# 572             (sex_MALE, flipper_length_mm_2.0, species_Gentoo, body_mass_g_2.0)
# 568              (flipper_length_mm_2.0, island_Biscoe, sex_MALE, body_mass_g_2.0)
# 399                              (sex_MALE, species_Gentoo, flipper_length_mm_2.0)
# 396                               (island_Biscoe, sex_MALE, flipper_length_mm_2.0)
# 410                                      (sex_MALE, island_Biscoe, species_Gentoo)
# 327                                                     (species_Gentoo, sex_MALE)
# 565               (sex_MALE, island_Biscoe, species_Gentoo, flipper_length_mm_2.0)
# 536                              (sex_MALE, species_Gentoo, flipper_length_mm_2.0)
# 442                               (island_Biscoe, sex_MALE, flipper_length_mm_2.0)
# 445                             (flipper_length_mm_2.0, sex_MALE, body_mass_g_2.0)
#
#                                                                        consequents  \
# 592  (culmen_length_mm_2.0, island_Biscoe, flipper_length_mm_2.0, body_mass_g_2.0)
# 570                                                     (sex_MALE, species_Gentoo)
# 420                         (island_Biscoe, culmen_length_mm_2.0, body_mass_g_2.0)
# 413                                                     (sex_MALE, species_Gentoo)
# 584                               (island_Biscoe, sex_MALE, flipper_length_mm_2.0)
# 579                              (sex_MALE, species_Gentoo, flipper_length_mm_2.0)
# 585                         (island_Biscoe, culmen_length_mm_2.0, body_mass_g_2.0)
# 580                        (culmen_length_mm_2.0, species_Gentoo, body_mass_g_2.0)
# 577                 (culmen_length_mm_2.0, flipper_length_mm_2.0, body_mass_g_2.0)
# 543                 (culmen_length_mm_2.0, flipper_length_mm_2.0, body_mass_g_2.0)
# 403                   (culmen_length_mm_2.0, island_Biscoe, flipper_length_mm_2.0)
# 583                   (culmen_length_mm_2.0, island_Biscoe, flipper_length_mm_2.0)
# 582                                    (sex_MALE, species_Gentoo, body_mass_g_2.0)
# 398                                                     (sex_MALE, species_Gentoo)
# 590                                      (sex_MALE, island_Biscoe, species_Gentoo)
# 541                                                     (sex_MALE, species_Gentoo)
# 415                                          (island_Biscoe, culmen_length_mm_2.0)
# 183                                                     (species_Gentoo, sex_MALE)
# 419                                    (sex_MALE, species_Gentoo, body_mass_g_2.0)
# 181                                          (island_Biscoe, culmen_length_mm_2.0)
# 572                                          (island_Biscoe, culmen_length_mm_2.0)
# 568                                         (culmen_length_mm_2.0, species_Gentoo)
# 399                                          (island_Biscoe, culmen_length_mm_2.0)
# 396                                         (culmen_length_mm_2.0, species_Gentoo)
# 410                                        (culmen_length_mm_2.0, body_mass_g_2.0)
# 327                                        (culmen_length_mm_2.0, body_mass_g_2.0)
# 565                                        (culmen_length_mm_2.0, body_mass_g_2.0)
# 536                                        (culmen_length_mm_2.0, body_mass_g_2.0)
# 442                                        (culmen_length_mm_2.0, body_mass_g_2.0)
# 445                                          (island_Biscoe, culmen_length_mm_2.0)
#
#       support  confidence      lift  conviction
# 592  0.150150    0.819672  4.264857    4.479661
# 570  0.150150    0.781250  4.264857    3.734020
# 420  0.153153    0.836066  4.218331    4.890991
# 413  0.153153    0.772727  4.218331    3.593994
# 584  0.150150    0.757576  4.204545    3.381757
# 579  0.150150    0.757576  4.204545    3.381757
# 585  0.150150    0.833333  4.204545    4.810811
# 580  0.150150    0.833333  4.204545    4.810811
# 577  0.150150    0.819672  4.199243    4.463008
# 543  0.150150    0.819672  4.199243    4.463008
# 403  0.150150    0.819672  4.199243    4.463008
# 583  0.150150    0.819672  4.199243    4.463008
# 582  0.150150    0.769231  4.199243    3.539540
# 398  0.150150    0.769231  4.199243    3.539540
# 590  0.150150    0.769231  4.199243    3.539540
# 541  0.150150    0.769231  4.199243    3.539540
# 415  0.153153    0.836066  4.155371    4.872673
# 183  0.153153    0.761194  4.155371    3.420420
# 419  0.153153    0.761194  4.155371    3.420420
# 181  0.153153    0.836066  4.155371    4.872673
# 572  0.150150    0.833333  4.141791    4.792793
# 568  0.150150    0.833333  4.141791    4.792793
# 399  0.150150    0.833333  4.141791    4.792793
# 396  0.150150    0.833333  4.141791    4.792793
# 410  0.153153    0.836066  4.094262    4.854354
# 327  0.153153    0.836066  4.094262    4.854354
# 565  0.150150    0.833333  4.080882    4.774775
# 536  0.150150    0.833333  4.080882    4.774775
# 442  0.150150    0.833333  4.080882    4.774775
# 445  0.150150    0.819672  4.073893    4.429702

# %% [markdown]
# g) En el futuro se puede, utilizar esta informacion para en caso de buscar un pinguino de la especie Gentoo ir a la isla Biscoe. Tambien pueden estudiar si por algun motivo especial en esa isla, los machos son mas grandes. O pueden predecir en el futuro las medidas de un pinguino de esa especie.
